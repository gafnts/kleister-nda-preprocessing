# %% [markdown]
# # DataLoader

# %%
import subprocess
import pandas as pd

from pathlib import Path
from typing import Literal

# %% [markdown]
# ## Load data and labels

# %%
class DataLoader:
    def __init__(self, data_dir: Path):
        self.data_dir = data_dir
        self._column_names = pd.read_csv(
            data_dir / "in-header.tsv", sep="\t", encoding="utf-8", nrows=0
        ).columns.tolist()

    def load(
        self, partition: Literal["train", "dev-0", "test-A"] = "train"
    ) -> pd.DataFrame:
        if partition == "test-A":
            return self._read_data(partition)
        return pd.concat(
            [self._read_data(partition), self._read_labels(partition)], axis=1
        )

    def _read_data(self, partition: str) -> pd.DataFrame:
        return pd.read_csv(
            self.data_dir / partition / "in.tsv.xz",
            sep="\t",
            encoding="utf-8",
            compression="xz",
            header=None,
            names=self._column_names,
        )

    def _read_labels(self, partition: str) -> pd.DataFrame:
        return pd.read_csv(
            self.data_dir / partition / "expected.tsv",
            sep="\t",
            encoding="utf-8",
            header=None,
            names=["labels"],
        )

# %%
loader = DataLoader(Path.cwd().parent / "static" / "data")
train, val, test = [
    loader.load(partition) for partition in ("train", "dev-0", "test-A")
]

# %% [markdown]
# ### Explore

# %%
def open_document(filename: str) -> None:
    pdf_path = loader.data_dir / "documents" / f"{filename}"
    subprocess.run(["open", pdf_path])


filename = "073f3b9eb0c7088be4ef688f4edfdb6d.pdf"

open_document(filename)

val.query(f"filename == '{filename}'").labels.to_list()
# Out:
# ['effective_date=2014-05-20 jurisdiction=New_York party=Liquidmetal_Technology_Inc. party=Visser_Precision_Cast_LLC term=3_years']

# %%
val.head(10)
# Out:
#                                filename  \
# 0  073f3b9eb0c7088be4ef688f4edfdb6d.pdf
# 1  0d3f3a02773949e285cfc3ad2fe4dbf5.pdf
# 2  0f32a3a54d9c1e42d26f66746821c3bf.pdf
# 3  0fe8eaee697774ac95f9186dd2fc3364.pdf
# 4  11d0a5b1f6e460c7033d57661026d00c.pdf
# 5  12fe8459ce606334afe537b24f476fa2.pdf
# 6  137b97581e7b68b665e86b37d0a25500.pdf
# 7  14b0b2208aaab4da5388590f9ed8e03c.pdf
# 8  159ce2a2e6936e25efdc717e2a623497.pdf
# 9  2572bba862c654e665039f634c132fea.pdf
#
#                                      keys  \
# 0  effective_date jurisdiction party term
# 1  effective_date jurisdiction party term
# 2  effective_date jurisdiction party term
# 3  effective_date jurisdiction party term
# 4  effective_date jurisdiction party term
# 5  effective_date jurisdiction party term
# 6  effective_date jurisdiction party term
# 7  effective_date jurisdiction party term
# 8  effective_date jurisdiction party term
# 9  effective_date jurisdiction party term
#
#                                            text_djvu  \
# 0  EX-10 5 ex10-4 .htm EXHIBIT 10.4\nExhibit 10.4...
# 1  Exhibit L-2\nto Amended and Restated Loan Guar...
# 2  EX-99.D.3 12 d438799dex99d3.htm AMENDED AND RE...
# 3  EX-10.1 2 a09-6413_1ex10d1.htm EX-10.1\nExhibi...
# 4  EX-99.(D)(3) 8 d901048dex99d3.htm CONFIDENTIAL...
# 5  EX-10 .10 3 ex101011112.htm EXHIBIT 10.10\nExh...
# 6  EX-99.(D)(4) 9 dex99d4.htm MUTUAL NON-DISCLOSU...
# 7  EX-10 .2 3 ex10-2.htm EXHIBIT 10.2\nExhibit 10...
# 8  EX-10 .6 .2 22 v321826_ex10-6x2.htm EXHIBIT 10...
# 9  EX-99.(D)(4) 9 d110802dex99d4.htm EX-99.(D)(4)...
#
#                                       text_tesseract  \
# 0  EX-10 5 ex10-4.htm EXHIBIT 10.4\nExhibit 10.4\...
# 1  Exhibit I.-2\nto Amended and Restated Loan Gua...
# 2  EX-99.D.3 12 d438799dex99d3.htm AMENDED AND RE...
# 3  EX-10.1 2 a09-6413_1ex10d1.htm EX-10.1\nExhibi...
# 4  EX-99.(D)(3) 8 d901048dex99d3.htm CONFIDENTIAL...
# 5  EX-10.10 3 ex101011112.htm EXHIBIT 10.10\nExhi...
# 6  EX-99.(D)(4) 9 dex99d4.htm MUTUAL NON-DISCLOSU...
# 7  EX-10.2 3 ex10-2.htm EXHIBIT 10.2\nExhibit 10....
# 8  EX-10.6.2 22 v321826_ex10-6x2.htm EXHIBIT 10.6...
# 9  EX-99.(D)(4) 9 d110802dex99d4.htm EX-99.(D)(4)...
#
#                                        text_textract  \
# 0  EX-10 ex10-4.htm EXHIBIT 10.4\nExhibit 10.4\nA...
# 1  Exhibit L-2\nto Amended and Restated Loan Guar...
# 2  EX-99.D.3 12 d438799dex99d3.htm AMENDED AND RE...
# 3  EX-10.1 2 a09-6413_1ex10d1.htm EX-10.1\nExhibi...
# 4  EX-99.(D)(3) 8 d901048dex99d3.htm CONFIDENTIAL...
# 5  EX-10.10 3 ex101011112.htm EXHIBIT 10.10\nExhi...
# 6  EX-99.(D)(4) 9 dex99d4.htm MUTUAL NON-DISCLOSU...
# 7  EX-10.2 ex10-2.htm EXHIBIT 10.2\nExhibit 10.2\...
# 8  EX-10.6.2 22 v321826_ex10-6x2.htm EXHIBIT 10.6...
# 9  EX-99.(D)(4) 9 d110802dex99d4.htm EX-99.(D)(4)...
#
#                                            text_best  \
# 0  EX-10 5 ex10-4 .htm EXHIBIT 10.4\nExhibit 10.4...
# 1  Exhibit L-2\nto Amended and Restated Loan Guar...
# 2  EX-99.D.3 12 d438799dex99d3.htm AMENDED AND RE...
# 3  EX-10.1 2 a09-6413_1ex10d1.htm EX-10.1\nExhibi...
# 4  EX-99.(D)(3) 8 d901048dex99d3.htm CONFIDENTIAL...
# 5  EX-10 .10 3 ex101011112.htm EXHIBIT 10.10\nExh...
# 6  EX-99.(D)(4) 9 dex99d4.htm MUTUAL NON-DISCLOSU...
# 7  EX-10 .2 3 ex10-2.htm EXHIBIT 10.2\nExhibit 10...
# 8  EX-10 .6 .2 22 v321826_ex10-6x2.htm EXHIBIT 10...
# 9  EX-99.(D)(4) 9 d110802dex99d4.htm EX-99.(D)(4)...
#
#                                               labels
# 0  effective_date=2014-05-20 jurisdiction=New_Yor...
# 1  jurisdiction=New_York party=Oglethorpe_Power_C...
# 2  effective_date=2012-09-04 jurisdiction=Delawar...
# 3  effective_date=2009-02-23 jurisdiction=Massach...
# 4  effective_date=2015-03-01 jurisdiction=Delawar...
# 5  effective_date=2012-01-11 jurisdiction=Washing...
# 6  effective_date=2009-04-30 jurisdiction=Delawar...
# 7  effective_date=2016-06-22 jurisdiction=New_Jer...
# 8  effective_date=2008-03-31 jurisdiction=New_Yor...
# 9  effective_date=2015-12-11 party=Anadigics_Inc....

# %% [markdown]
# ## Backlog
#
# - Define Pydantic schema
# - We'll need a way to format labels into JSON and back
